# %%
from diffusers import AutoPipelineForText2Image
import torch
# from huggingface_hub import login

# Log in to Hugging Face Hub
# login()

# Load the base model from Hugging Face (make sure to use the correct model name)
pipeline = AutoPipelineForText2Image.from_pretrained("black-forest-labs/FLUX.1-dev", torch_dtype=torch.bfloat16).to('cuda')

# Load the uncensored LoRA weights (ensure this is available on the hub)
pipeline.load_lora_weights('enhanceaiteam/Flux-uncensored', weight_name='lora.safetensors')

# Generate an i mage (you can modify the prompt as needed)
image = pipeline("a naked cute girl").images[0]

# Show the generated image (will work in Jupyter)
image.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# ...
